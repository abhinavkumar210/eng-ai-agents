# %% [markdown]
# # Project — Part 0: Environment Change
#
# Abhinav Kumar
# 12/7/2025

# %%
import torch
import cv2
from PIL import Image
import numpy as np
import requests
from pymongo import MongoClient
import transformers
from pydantic_ai import Agent

print("Torch:", torch.__version__)
import transformers as tfm
print("Transformers:", tfm.__version__)
print("Imports OK")
# Out:
# Torch: 2.8.0+cpu
# Transformers: 4.57.3
# Imports OK

# %% [markdown]
# # DS681 Midterm Assignment
# Abhinav Kumar
#
# This notebook implements Zhang's camera calibration.
# Using: NumPy, SciPy, PyTorch, Pandas; Kornia helpers only

# %%
import numpy as np
import pandas as pd
from pathlib import Path, PurePosixPath
from PIL import Image
from huggingface_hub import login
from scipy.ndimage import gaussian_filter, sobel
import os

tok = os.getenv("HUGGINGFACE_TOKEN")
if tok: login(tok)

SOURCE_PARQUET = "hf://datasets/pantelism/wide-camera-calibration/data/train-00000-of-00001.parquet"
IMAGE_BASE_DIR = "."
NUM_COLS, NUM_ROWS = 9, 7
SQUARE_SIZE_M = 0.025
OUTPUT_PARQUET = "corner_annotations.parquet"
RANDOM_SUBSAMPLE = None

print("Config OK")
# Out:
# Config OK

# %%
import matplotlib as mpl

for b in ["notebook", "nbagg", "qtagg", "qt5agg", "tkagg", "webagg"]:
    try:
        mpl.use(b, force=True)
        import matplotlib.pyplot as plt
        plt.figure(); plt.close()
        print("Using backend:", mpl.get_backend())
        break
    except Exception:
        pass
else:
    raise RuntimeError("No usable interactive backend found. Install a GUI (Qt/Tk) or use Jupyter Notebook 'notebook' mode.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[107], line 14
#      12         pass
#      13 else:
# ---> 14     mpl.use("agg", force=True)
#      15     import matplotlib.pyplot as plt
#      16     chosen = "agg"
#
# File /workspaces/eng-ai-agents/.venv/lib/python3.11/site-packages/matplotlib/__init__.py:1284, in use(backend, force)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /workspaces/eng-ai-agents/.venv/lib/python3.11/site-packages/matplotlib/pyplot.py:519, in switch_backend(newbackend)
#     482 def show(*args, **kwargs) -> None:
#     483     """
#     484     Display all open figures.
#     485
#     486     Parameters
#     487     ----------
#     488     block : bool, optional
#     489         Whether to wait for all figures to be closed before returning.
#     490
#     491         If `True` block and run the GUI main loop until all figure windows
#     492         are closed.
#     493
#     494         If `False` ensure that all figure windows are displayed and return
#     495         immediately.  In this case, you are responsible for ensuring
#     496         that the event loop is running to have responsive figures.
#     497
#     498         Defaults to True in non-interactive mode and to False in interactive
#     499         mode (see `.pyplot.isinteractive`).
#     500
#     501     See Also
#     502     --------
#     503     ion : Enable interactive mode, which shows / updates the figure after
#     504           every plotting command, so that calling ``show()`` is not necessary.
#     505     ioff : Disable interactive mode.
#     506     savefig : Save the figure to an image file instead of showing it on screen.
#     507
#     508     Notes
#     509     -----
#     510     **Saving figures to file and showing a window at the same time**
#     511
#     512     If you want an image file as well as a user interface window, use
#     513     `.pyplot.savefig` before `.pyplot.show`. At the end of (a blocking)
#     514     ``show()`` the figure is closed and thus unregistered from pyplot. Calling
#     515     `.pyplot.savefig` afterwards would save a new and thus empty figure. This
#     516     limitation of command order does not apply if the show is non-blocking or
#     517     if you keep a reference to the figure and use `.Figure.savefig`.
#     518
# --> 519     **Auto-show in jupyter notebooks**
#     520
#     521     The jupyter backends (activated via ``%matplotlib inline``,
#     522     ``%matplotlib notebook``, or ``%matplotlib widget``), call ``show()`` at
#     523     the end of every cell by default. Thus, you usually don't have to call it
#     524     explicitly there.
#     525     """
#     526     _warn_if_gui_out_of_main_thread()
#     527     return _get_backend_mod().show(*args, **kwargs)
#
# File /workspaces/eng-ai-agents/.venv/lib/python3.11/site-packages/matplotlib/_api/__init__.py:218, in __getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
#     217 raise AttributeError(
# --> 218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'backends'

# %%
EXTRACT_DIR = Path(IMAGE_BASE_DIR) / "_images"
EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

def load_image_table(parquet_path, out_dir):
    df = pd.read_parquet(parquet_path)
    if "image" not in df.columns and "filename" in df.columns:
        df = df.rename(columns={"filename": "image"})
    if "image" not in df.columns:
        raise ValueError(f"Need an 'image' or 'filename' column. Got: {sorted(df.columns)}")

    ids, paths = [], []
    for i, row in df.reset_index(drop=True).iterrows():
        img = row["image"]
        img_id = row["image_id"] if "image_id" in row else f"img_{i:04d}"

        if isinstance(img, dict) and "bytes" in img:
            ext = PurePosixPath(img.get("path","")).suffix or ".jpg"
            p = out_dir / f"{img_id}{ext}"
            with open(p, "wb") as f:
                f.write(img["bytes"])
            ids.append(str(img_id))
            paths.append(str(p))
        elif isinstance(img, str):
            ids.append(str(img_id))
            paths.append(str(Path(img)))
        else:
            continue

    return pd.DataFrame({"image_id": ids, "image": paths})

df_images = load_image_table(SOURCE_PARQUET, out_dir=EXTRACT_DIR)
if RANDOM_SUBSAMPLE:
    df_images = df_images.sample(n=min(RANDOM_SUBSAMPLE, len(df_images)), random_state=42).reset_index(drop=True)

print(f"Loaded {len(df_images)} images → {EXTRACT_DIR}")
df_images.head()
# Out:
# Loaded 44 images → _images
#    image_id                 image
# 0  img_0000  _images/img_0000.jpg
# 1  img_0001  _images/img_0001.jpg
# 2  img_0002  _images/img_0002.jpg
# 3  img_0003  _images/img_0003.jpg
# 4  img_0004  _images/img_0004.jpg

# %%
def harris_response(gray, k=0.04, sigma=1.5):
    g = gray.astype(np.float32) / 255.0
    Ix = sobel(g, axis=1)
    Iy = sobel(g, axis=0)
    Ixx = gaussian_filter(Ix * Ix, sigma=sigma)
    Iyy = gaussian_filter(Iy * Iy, sigma=sigma)
    Ixy = gaussian_filter(Ix * Iy, sigma=sigma)
    det = Ixx * Iyy - Ixy * Ixy
    tr = Ixx + Iyy
    return det - k * (tr ** 2)

def local_max_in_window(resp, cx, cy, rad=7):
    h, w = resp.shape
    x0 = max(int(round(cx)) - rad, 0)
    x1 = min(int(round(cx)) + rad + 1, w)
    y0 = max(int(round(cy)) - rad, 0)
    y1 = min(int(round(cy)) + rad + 1, h)
    if x0 >= x1 or y0 >= y1:
        return int(round(cx)), int(round(cy))
    win = resp[y0:y1, x0:x1]
    yy, xx = np.unravel_index(np.argmax(win), win.shape)
    return x0 + xx, y0 + yy

def subpixel_quadratic(resp, x, y):
    h, w = resp.shape
    xi = int(np.clip(x, 1, w - 2))
    yi = int(np.clip(y, 1, h - 2))
    W = resp[yi-1:yi+2, xi-1:xi+2]
    xs, ys = np.meshgrid([-1, 0, 1], [-1, 0, 1])
    A = np.column_stack([xs.ravel()**2, ys.ravel()**2, (xs*ys).ravel(), xs.ravel(), ys.ravel(), np.ones(9)])
    z = W.ravel()
    try:
        a,b,c,d,e,f = np.linalg.lstsq(A, z, rcond=None)[0]
        M = np.array([[2*a, c],[c, 2*b]], dtype=np.float32)
        v = np.array([-d, -e], dtype=np.float32)
        if np.linalg.cond(M) < 1e4:
            off = np.linalg.solve(M, v)
            offx = float(np.clip(off[0], -1, 1)); offy = float(np.clip(off[1], -1, 1))
        else:
            offx = offy = 0.0
    except:
        offx = offy = 0.0
    return xi + offx, yi + offy

# %%
def propose_grid_from_three_clicks(num_cols, num_rows, clicks):
    (TLx,TLy), (TRx,TRy), (BLx,BLy) = clicks
    TL = np.array([TLx, TLy], np.float32)
    TR = np.array([TRx, TRy], np.float32)
    BL = np.array([BLx, BLy], np.float32)
    vx = (TR - TL) / max(num_cols - 1, 1)
    vy = (BL - TL) / max(num_rows - 1, 1)
    pts = []
    for r in range(num_rows):
        for c in range(num_cols):
            p = TL + c*vx + r*vy
            pts.append([p[0], p[1], c, r])
    return np.array(pts, np.float32)

# %%
def semi_auto_annotate_image(img_path, num_cols, num_rows, search_rad=7, k=0.04, sigma=1.5, show=True):
    gray = np.array(Image.open(img_path).convert("L"), dtype=np.uint8)
    plt.figure(figsize=(10,8)); plt.imshow(gray, cmap='gray')
    plt.title("Click: TOP-LEFT, TOP-RIGHT, BOTTOM-LEFT")
    clicks = plt.ginput(n=3, timeout=0, show_clicks=True)
    plt.close()
    if len(clicks) != 3:
        raise RuntimeError("Need 3 clicks.")

    init = propose_grid_from_three_clicks(num_cols, num_rows, clicks)
    resp = harris_response(gray, k=k, sigma=sigma)

    refined = []
    for (u0, v0, c, r) in init:
        xi, yi = local_max_in_window(resp, u0, v0, rad=search_rad)
        ux, vy = subpixel_quadratic(resp, xi, yi)
        refined.append([ux, vy, int(c), int(r)])
    refined = np.array(refined, np.float32)

    if show:
        plt.figure(figsize=(10,8)); plt.imshow(gray, cmap='gray')
        plt.scatter(init[:,0], init[:,1], s=10, label='init')
        plt.scatter(refined[:,0], refined[:,1], s=12, label='refined')
        for (u0,v0,_,_), (ux,vy,_,_) in zip(init, refined):
            plt.plot([u0, ux], [v0, vy])
        plt.legend(); plt.show()

    return pd.DataFrame(refined, columns=["u","v","col","row"])

# %%
def semi_auto_annotate_images(df_images, image_base_dir, num_cols, num_rows, square_size_m,
                              out_parquet="corner_annotations.parquet", search_rad=7, k=0.04, sigma=1.5):
    rows = []
    for _, r in df_images.iterrows():
        image_id = r["image_id"]
        img_path = (Path(image_base_dir) / r["image"]).resolve()
        if not img_path.exists():
            print(f"[WARN] missing {img_path}, skip"); continue
        print(f"\nImage: {img_path}")
        try:
            df = semi_auto_annotate_image(str(img_path), num_cols, num_rows,
                                          search_rad=search_rad, k=k, sigma=sigma, show=True)
            ans = input("Accept? [y/n]: ").strip().lower()
            if ans == "y":
                df["image_id"] = image_id
                df["X"] = df["col"] * float(square_size_m)
                df["Y"] = df["row"] * float(square_size_m)
                rows.append(df)
                print("Saved.")
            else:
                print("Discarded.")
        except Exception as e:
            print(f"[ERROR] {img_path}: {e}")
    if not rows:
        raise RuntimeError("No accepted annotations.")
    out = pd.concat(rows, ignore_index=True)
    out.to_parquet(out_parquet, index=False)
    print(f"Wrote {len(out)} rows to {out_parquet}")
    return out

# %%
_ = semi_auto_annotate_images(
    df_images=df_images,
    image_base_dir=IMAGE_BASE_DIR,
    num_cols=NUM_COLS,
    num_rows=NUM_ROWS,
    square_size_m=SQUARE_SIZE_M,
    out_parquet=OUTPUT_PARQUET,
    search_rad=9,
    k=0.04,
    sigma=1.2
)
# Out:
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0000.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0000.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0001.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0001.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0002.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0002.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0003.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0003.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0004.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0004.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0005.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0005.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0006.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0006.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0007.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0007.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0008.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0008.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0009.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0009.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0010.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0010.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0011.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0011.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0012.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0012.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0013.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0013.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0014.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0014.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0015.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0015.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0016.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0016.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0017.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0017.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0018.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0018.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0019.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0019.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0020.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0020.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0021.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0021.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0022.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0022.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0023.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0023.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0024.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0024.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0025.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0025.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0026.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0026.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0027.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0027.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0028.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0028.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0029.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0029.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0030.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0030.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0031.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0031.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0032.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0032.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0033.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0033.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0034.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0034.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0035.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0035.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0036.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0036.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0037.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0037.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0038.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0038.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0039.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0039.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0040.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0040.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0041.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0041.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0042.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0042.jpg: module 'matplotlib' has no attribute 'colors'
#
# Image: /workspaces/eng-ai-agents/assignments/midterm/_images/img_0043.jpg
# [ERROR] /workspaces/eng-ai-agents/assignments/midterm/_images/img_0043.jpg: module 'matplotlib' has no attribute 'colors'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 _ = semi_auto_annotate_images(
#       2     df_images=df_images,
#       3     image_base_dir=IMAGE_BASE_DIR,
#       4     num_cols=NUM_COLS,
#       5     num_rows=NUM_ROWS,
#       6     square_size_m=SQUARE_SIZE_M,
#       7     out_parquet=OUTPUT_PARQUET,
#       8     search_rad=9,
#       9     k=0.04,
#      10     sigma=1.2
#      11 )
#
# Cell In[99], line 25, in semi_auto_annotate_images(df_images, image_base_dir, num_cols, num_rows, square_size_m, out_parquet, search_rad, k, sigma)
#      23         print(f"[ERROR] {img_path}: {e}")
#      24 if not rows:
# ---> 25     raise RuntimeError("No accepted annotations.")
#      26 out = pd.concat(rows, ignore_index=True)
#      27 out.to_parquet(out_parquet, index=False)
#
# RuntimeError: No accepted annotations.

# %%
df = pd.read_parquet(OUTPUT_PARQUET)
print(df.shape)
df.head()

# %%
from pathlib import Path
import matplotlib as mpl, sys

print("matplotlib loaded from:", mpl.__file__)
print("cwd has matplotlib.py? ", Path("matplotlib.py").exists())
print("cwd has 'matplotlib' dir? ", Path("matplotlib").is_dir())
# Out:
# matplotlib loaded from: /workspaces/eng-ai-agents/.venv/lib/python3.11/site-packages/matplotlib/__init__.py
# cwd has matplotlib.py?  False
# cwd has 'matplotlib' dir?  False
